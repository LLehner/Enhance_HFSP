# %%
import pandas as pd
import os
import seaborn as sns
from collections import Counter
import shutil
from matplotlib import rcParams
import matplotlib.pyplot as plt

rcParams['figure.figsize'] = 25, 5

# %%
def extract_first_three_levels(ec_number):
    levels = ec_number.split('.')
    return '.'.join(levels[:3])

# %%
# Get list of IDs in redundancy reduced 2002 dataset
data_ids = [item.replace('.pdb', '') for item in os.listdir("testing/2_after_redundancy_reduction/Swiss-Prot_2002_redundancy_reduced")]
data_ids[:10]
# Out:
# ['P46010',
#  'P50861',
#  'P48825',
#  'P16184',
#  'Q05116',
#  'Q12001',
#  'P13051',
#  'P26829',
#  'P04841',
#  'P54751']

# %%
data = pd.read_excel("testing/hfsp_supplement/Mahlich.335.sup.data.1.xlsx", sheet_name="Swiss-Prot 2002")

# Create EC_3 column
data["ec3"] = data["ec_number"].apply(extract_first_three_levels)

# Filter for proteins after redundancy reduction
data = data[data['id'].isin(data_ids)]

data
# Out:
#           id   ec_number    domain      ec3
# 0     P00533    2.7.10.1   Eukarya   2.7.10
# 2     P21802    2.7.10.1   Eukarya   2.7.10
# 4     P11362    2.7.10.1   Eukarya   2.7.10
# 5     P04626    2.7.10.1   Eukarya   2.7.10
# 6     P10721    2.7.10.1   Eukarya   2.7.10
# ...      ...         ...       ...      ...
# 3903  P53228     2.2.1.2   Eukarya    2.2.1
# 3904  P48775  1.13.11.11   Eukarya  1.13.11
# 3905  P77806    2.6.1.88  Bacteria    2.6.1
# 3906  P14680    2.7.12.1   Eukarya   2.7.12
# 3907  P36217     3.2.1.8   Eukarya    3.2.1
#
# [3768 rows x 4 columns]

# %%
sns.set_theme(font_scale = 2, style="whitegrid")

hist = sns.histplot(list(Counter(data["ec3"]).values()), binwidth=1, color='darkblue')
hist.set(xlabel = "# Proteins per EC category", ylabel = "# EC category", xlim=(-17, 350), ylim=(0, 30))

#plt.setp(hist.get_xlabel(), fontsize=14)
#plt.setp(hist.get_ylabel(), fontsize=14)
# Out:
# [Text(0.5, 0, '# Proteins per EC category'),
#  Text(0, 0.5, '# EC category'),
#  (-17.0, 350.0),
#  (0.0, 30.0)]

# %%
data
# Out:
#           id   ec_number    domain      ec3
# 0     P00533    2.7.10.1   Eukarya   2.7.10
# 2     P21802    2.7.10.1   Eukarya   2.7.10
# 4     P11362    2.7.10.1   Eukarya   2.7.10
# 5     P04626    2.7.10.1   Eukarya   2.7.10
# 6     P10721    2.7.10.1   Eukarya   2.7.10
# ...      ...         ...       ...      ...
# 3903  P53228     2.2.1.2   Eukarya    2.2.1
# 3904  P48775  1.13.11.11   Eukarya  1.13.11
# 3905  P77806    2.6.1.88  Bacteria    2.6.1
# 3906  P14680    2.7.12.1   Eukarya   2.7.12
# 3907  P36217     3.2.1.8   Eukarya    3.2.1
#
# [3768 rows x 4 columns]

# %%
Counter(data["ec3"])
# Out:
# Counter({'2.7.11': 330,
#          '2.7.10': 170,
#          '1.1.1': 136,
#          '3.2.1': 129,
#          '2.7.1': 113,
#          '2.1.1': 110,
#          '2.3.1': 108,
#          '2.5.1': 97,
#          '4.1.1': 97,
#          '3.4.21': 93,
#          '2.4.1': 92,
#          '3.1.3': 85,
#          '4.2.1': 81,
#          '6.1.1': 74,
#          '2.7.7': 66,
#          '3.5.1': 56,
#          '3.1.4': 56,
#          '3.4.22': 55,
#          '3.1.1': 54,
#          '3.4.24': 44,
#          '1.2.1': 44,
#          '5.3.1': 41,
#          '2.6.1': 41,
#          '2.4.2': 39,
#          '2.7.13': 39,
#          '2.7.12': 38,
#          '3.6.3': 37,
#          '1.14.13': 36,
#          '1.11.1': 34,
#          '2.7.4': 32,
#          '3.6.1': 31,
#          '1.4.3': 30,
#          '4.1.2': 28,
#          '1.13.11': 28,
#          '3.5.2': 28,
#          '6.3.2': 28,
#          '3.5.4': 27,
#          '3.4.23': 26,
#          '5.4.99': 26,
#          '3.6.4': 25,
#          '1.5.1': 25,
#          '4.6.1': 24,
#          '6.3.4': 23,
#          '2.3.3': 23,
#          '3.4.11': 23,
#          '1.3.1': 23,
#          '2.4.99': 20,
#          '4.4.1': 19,
#          '1.4.1': 19,
#          '2.2.1': 18,
#          '3.2.2': 18,
#          '3.5.3': 18,
#          '6.3.1': 18,
#          '2.7.2': 17,
#          '1.6.5': 17,
#          '3.1.26': 17,
#          '4.2.3': 16,
#          '4.3.1': 15,
#          '6.2.1': 15,
#          '5.4.2': 15,
#          '1.15.1': 14,
#          '5.2.1': 14,
#          '3.4.19': 14,
#          '6.5.1': 14,
#          '5.99.1': 13,
#          '4.1.3': 13,
#          '1.8.1': 13,
#          '5.3.3': 13,
#          '2.7.3': 13,
#          '3.1.21': 12,
#          '2.8.1': 12,
#          '4.2.2': 12,
#          '3.4.17': 12,
#          '3.4.14': 11,
#          '3.1.27': 11,
#          '1.7.2': 10,
#          '2.8.2': 10,
#          '1.3.3': 10,
#          '6.3.5': 10,
#          '3.4.16': 10,
#          '5.5.1': 10,
#          '1.14.14': 10,
#          '1.12.98': 10,
#          '2.1.3': 10,
#          '1.1.3': 9,
#          '3.1.2': 9,
#          '4.3.3': 9,
#          '5.3.4': 9,
#          '1.14.11': 8,
#          '5.1.1': 8,
#          '2.8.3': 8,
#          '5.3.99': 8,
#          '2.8.4': 8,
#          '2.7.9': 8,
#          '1.17.4': 8,
#          '4.1.99': 7,
#          '1.14.16': 7,
#          '1.18.1': 7,
#          '1.14.99': 7,
#          '3.6.5': 7,
#          '5.1.3': 7,
#          '2.3.2': 6,
#          '6.4.1': 6,
#          '1.3.8': 6,
#          '1.2.3': 6,
#          '1.14.19': 6,
#          '1.8.3': 6,
#          '3.1.6': 6,
#          '1.2.7': 6,
#          '1.10.3': 6,
#          '1.8.4': 6,
#          '2.1.2': 6,
#          '1.3.5': 6,
#          '4.99.1': 6,
#          '3.5.5': 6,
#          '3.4.13': 5,
#          '1.3.99': 5,
#          '3.8.1': 5,
#          '3.7.1': 5,
#          '1.9.3': 5,
#          '3.1.11': 5,
#          '1.4.7': 5,
#          '1.1.5': 5,
#          '1.2.4': 5,
#          '1.6.2': 5,
#          '1.7.1': 5,
#          '3.5.99': 4,
#          '1.13.12': 4,
#          '1.1.99': 4,
#          '5.1.99': 4,
#          '4.3.2': 4,
#          '1.3.7': 4,
#          '1.14.15': 4,
#          '1.12.1': 4,
#          '2.7.8': 3,
#          '3.4.15': 3,
#          '1.17.99': 3,
#          '1.14.12': 3,
#          '1.16.3': 3,
#          '1.1.2': 3,
#          '3.1.22': 3,
#          '3.1.13': 3,
#          '2.1.4': 3,
#          '3.3.2': 3,
#          '6.3.3': 3,
#          '1.97.1': 3,
#          '2.7.6': 2,
#          '1.14.18': 2,
#          '1.14.17': 2,
#          '5.3.2': 2,
#          '4.2.99': 2,
#          '4.5.1': 2,
#          '1.17.1': 2,
#          '1.11.2': 2,
#          '1.5.3': 2,
#          '5.4.3': 2,
#          '5.4.4': 2,
#          '1.21.3': 2,
#          '1.18.6': 2,
#          '1.6.1': 2,
#          '1.12.2': 2,
#          '3.3.1': 2,
#          '1.7.3': 1,
#          '6.1.2': 1,
#          '6.6.1': 1,
#          '3.4.18': 1,
#          '1.14.20': 1,
#          '1.8.5': 1,
#          '1.6.99': 1,
#          '1.5.99': 1,
#          '1.5.5': 1,
#          '1.8.7': 1,
#          '1.8.98': 1,
#          '1.4.4': 1,
#          '2.10.1': 1,
#          '1.2.99': 1,
#          '1.5.8': 1,
#          '5.1.2': 1,
#          '1.12.99': 1,
#          '1.5.98': 1,
#          '1.7.7': 1,
#          '1.7.6': 1,
#          '3.1.30': 1,
#          '3.1.31': 1,
#          '4.7.1': 1,
#          '1.2.5': 1,
#          '2.9.1': 1,
#          '3.13.1': 1,
#          '3.10.1': 1})

# %%
def sample_group(group):
    return group.sample(min(len(group), 50), random_state=42)

data_50 = data.groupby('ec3').apply(sample_group).reset_index(drop=True)
data_50
# Out:
# /tmp/ipykernel_3420481/970966988.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data_50 = data.groupby('ec3').apply(sample_group).reset_index(drop=True)
#           id  ec_number    domain    ec3
# 0     P41562   1.1.1.42   Eukarya  1.1.1
# 1     Q59477  1.1.1.202  Bacteria  1.1.1
# 2     Q00055    1.1.1.8   Eukarya  1.1.1
# 3     P40288   1.1.1.47  Bacteria  1.1.1
# 4     Q38707  1.1.1.255   Eukarya  1.1.1
# ...      ...        ...       ...    ...
# 2711  O87703    6.5.1.2  Bacteria  6.5.1
# 2712  P49916    6.5.1.1   Eukarya  6.5.1
# 2713  Q08387    6.5.1.1   Eukarya  6.5.1
# 2714  Q9HH07    6.5.1.6   Archaea  6.5.1
# 2715  P26239    6.6.1.1  Bacteria  6.6.1
#
# [2716 rows x 4 columns]

# %%
hist2 = sns.histplot(list(Counter(data_50["ec3"]).values()), binwidth=1, color='darkblue')
hist2.set(xlabel = "# Proteins per EC category", ylabel = "# EC category", xlim=(-17, 350), ylim=(0, 30))
# Out:
# [Text(0.5, 0, '# Proteins per EC category'),
#  Text(0, 0.5, '# EC category'),
#  (-17.0, 350.0),
#  (0.0, 30.0)]

# %%
data_50
# Out:
#           id  ec_number    domain    ec3
# 0     P41562   1.1.1.42   Eukarya  1.1.1
# 1     Q59477  1.1.1.202  Bacteria  1.1.1
# 2     Q00055    1.1.1.8   Eukarya  1.1.1
# 3     P40288   1.1.1.47  Bacteria  1.1.1
# 4     Q38707  1.1.1.255   Eukarya  1.1.1
# ...      ...        ...       ...    ...
# 2711  O87703    6.5.1.2  Bacteria  6.5.1
# 2712  P49916    6.5.1.1   Eukarya  6.5.1
# 2713  Q08387    6.5.1.1   Eukarya  6.5.1
# 2714  Q9HH07    6.5.1.6   Archaea  6.5.1
# 2715  P26239    6.6.1.1  Bacteria  6.6.1
#
# [2716 rows x 4 columns]

# %%
#source = "testing/Swiss-Prot_2002_redundancy_reduced"
#target = "testing/Swiss-Prot_2002_redundancy_reduced_50"

# Subset PDB files to data_50 entries
#if not os.path.exists(target):
#    os.makedirs(target)

#for pdb_id in data_50["id"]:
#    protein_source_path = os.path.join(source, f"{pdb_id}.pdb")
#    protein_target_path = os.path.join(target, f"{pdb_id}.pdb")
#    if os.path.exists(protein_source_path):
#        shutil.copy(protein_source_path, protein_target_path)
#    else:
#        raise ValueError(f"source/{pdb_id}.pdb not found")

# %%
#data_50.to_csv("testing/Swiss-Prot_2002_redundancy_reduced_50.tsv", sep="\t", index=False)
